# %%
import http.client
import json
import os
import pandas as pd
import time
import numpy as np

# %%
API_SOCCER = os.environ.get("API_SOCCER")

# %% [markdown]
# # Collecting Data

# %%
connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': API_SOCCER }

# %%
# Eredivisie, Premier League, Bundesliga, Ligue 1, Serie A, Primera Divison
competitions = ['DED', 'PL', 'BL1', 'FL1', 'SA', 'PD']
seasons = [2018,2019,2020]

# %%
## Retreiving the data
for comp in competitions:
    for season in seasons:
        connection.request('GET', f"/v2/competitions/{comp}/matches?season={season}&status=FINISHED", None, headers )
        response = json.loads(connection.getresponse().read().decode())
        
        # Creating the empty DataFrame
        matches = pd.DataFrame()
        
        # Appending every match the the newly created DataFrame
        for match in response['matches']:
            matches = matches.append(match, ignore_index=True)
            
        ## Preprocessing
        # Correct type for ID and setting as index
        matches['id'] = matches['id'].astype('int32')
        matches = matches.set_index('id')
        matches.index = matches.index.astype('int64')
        # Remove odds
        matches = matches.drop(columns=['odds'])
        # Include winner as separate column
        matches['winner'] = [d.get('winner') for d in matches.score]
        # Include home team and away team as separate column
        matches['homeTeamName'] = [d.get('name') for d in matches.homeTeam]
        matches['awayTeamName'] = [d.get('name') for d in matches.awayTeam]
        
        ## Saving the data
        matches.to_csv(f"data/{comp}_{season}.csv")
        matches.to_pickle(f"data/{comp}_{season}.pickle")
        
        # Sleep 10 seconds, because we only have 10 calls per minute
        time.sleep(10)

# %% [markdown]
# ## Combining datasets into a big one
# We will first add a column indicating whether or not the date was pre/post corona, and then combine all datasets

# %%
# Eredivisie, Premier League, Bundesliga, Ligue 1, Serie A, Primera Divison
competitions = ['DED', 'PL', 'BL1', 'FL1', 'SA', 'PD']
seasons = [2018]

# %%
for comp in competitions:
    for season in seasons:
        df = pd.read_pickle(f"data/{comp}_{season}.pickle")
        df["corona"] = "pre"
        df.to_pickle(f"data/{comp}_{season}.pickle")

# %%
# Eredivisie, Premier League, Bundesliga, Ligue 1, Serie A, Primera Divison
competitions = ['DED', 'PL', 'BL1', 'FL1', 'SA', 'PD']
seasons = [2019]

# %%
# Dates manually looked up on worldfootball.net

for comp in competitions:
    for season in seasons:
        df = pd.read_pickle(f"data/{comp}_{season}.pickle")
        df["utcDate"] = pd.to_datetime(df["utcDate"]).dt.tz_localize(None)
        if comp == 'DED':
            df["corona"] = "pre"
            df.to_pickle(f"data/{comp}_{season}.pickle")
        elif comp == "PL":
            #1st of March, last game with fans
            df["corona"]= np.where(df["utcDate"] <= pd.Timestamp("2020-03-01").floor('D'),"pre","post")
            df.to_pickle(f"data/{comp}_{season}.pickle")
        elif comp == "BL1":
            #8th of March, last game with fans
            df["corona"]= np.where(df["utcDate"] <= pd.Timestamp("2020-03-08").floor('D'),"pre","post")
            df.to_pickle(f"data/{comp}_{season}.pickle")
        elif comp == "FL1":
            df["corona"] = "pre"
            df.to_pickle(f"data/{comp}_{season}.pickle")
        elif comp == "SA":
            #1st of March, last game with fans
            df["corona"]= np.where(df["utcDate"] <= pd.Timestamp("2020-03-01").floor('D'),"pre","post")
            df.to_pickle(f"data/{comp}_{season}.pickle")
        elif comp == "PD":
            #8th of March, last game with fans
            df["corona"]= np.where(df["utcDate"] <= pd.Timestamp("2020-03-08").floor('D'),"pre","post")            
            df.to_pickle(f"data/{comp}_{season}.pickle")

# %%
# Eredivisie, Premier League, Bundesliga, Ligue 1, Serie A, Primera Divison
competitions = ['DED', 'PL', 'BL1', 'FL1', 'SA', 'PD']
seasons = [2020]

# %%
for comp in competitions:
    for season in seasons:
        df = pd.read_pickle(f"data/{comp}_{season}.pickle")
        df["corona"] = "post"
        df.to_pickle(f"data/{comp}_{season}.pickle")

# %%
# Eredivisie, Premier League, Bundesliga, Ligue 1, Serie A, Primera Divison
competitions = ['DED', 'PL', 'BL1', 'FL1', 'SA', 'PD']
seasons = [2018,2019,2020]

# %%
final_df = pd.DataFrame()

for comp in competitions:
    for season in seasons:
        df = pd.read_pickle(f"data/{comp}_{season}.pickle")
        df["utcDate"] = pd.to_datetime(df["utcDate"]).dt.tz_localize(None)
        df["league"] = comp
        df["season"] = season
        final_df = final_df.append(df)
        
final_df.to_pickle("data/all_data.pickle")
final_df.to_csv("data/all_data.csv")

# %%
final_df
# Out:
#                                        awayTeam           group  \
# id
# 235183     {'id': 673, 'name': 'SC Heerenveen'}  Regular Season
# 235184   {'id': 671, 'name': 'Heracles Almelo'}  Regular Season
# 235185         {'id': 668, 'name': 'VVV Venlo'}  Regular Season
# 235186        {'id': 676, 'name': 'FC Utrecht'}  Regular Season
# 235187  {'id': 1920, 'name': 'Fortuna Sittard'}  Regular Season
# ...                                         ...             ...
# 308408      {'id': 94, 'name': 'Villarreal CF'}  Regular Season
# 308409         {'id': 83, 'name': 'Granada CF'}  Regular Season
# 308406  {'id': 263, 'name': 'Deportivo Alavés'}  Regular Season
# 308410      {'id': 77, 'name': 'Athletic Club'}  Regular Season
# 308404     {'id': 86, 'name': 'Real Madrid CF'}  Regular Season
#
#                                              homeTeam           lastUpdated  \
# id
# 235183              {'id': 684, 'name': 'PEC Zwolle'}  2019-04-13T17:30:48Z
# 235184                {'id': 678, 'name': 'AFC Ajax'}  2019-04-13T17:30:48Z
# 235185       {'id': 672, 'name': 'Willem II Tilburg'}  2019-04-13T17:30:48Z
# 235186                     {'id': 674, 'name': 'PSV'}  2019-04-13T17:30:48Z
# 235187           {'id': 670, 'name': 'SBV Excelsior'}  2019-04-13T17:30:48Z
# ...                                               ...                   ...
# 308408                {'id': 82, 'name': 'Getafe CF'}  2020-11-14T08:33:17Z
# 308409  {'id': 92, 'name': 'Real Sociedad de Fútbol'}  2020-11-14T08:33:17Z
# 308406               {'id': 88, 'name': 'Levante UD'}  2020-11-14T08:33:17Z
# 308410      {'id': 250, 'name': 'Real Valladolid CF'}  2020-11-14T08:33:17Z
# 308404              {'id': 95, 'name': 'Valencia CF'}  2020-11-14T08:33:17Z
#
#        matchday                                           referees  \
# id
# 235183        1  [{'id': 43861, 'name': 'Dennis Higler', 'natio...
# 235184        1  [{'id': 43858, 'name': 'Serdar Gözübüyük', 'na...
# 235185        1  [{'id': 17141, 'name': 'Rob Dieperink', 'natio...
# 235186        1  [{'id': 56905, 'name': 'Bas Nijhuis', 'nationa...
# 235187        1  [{'id': 56902, 'name': 'Siemen Mulder', 'natio...
# ...         ...                                                ...
# 308408        9  [{'id': 58184, 'name': 'José Luis Munuera', 'n...
# 308409        9  [{'id': 43843, 'name': 'Carlos del Cerro', 'na...
# 308406        9  [{'id': 57930, 'name': 'Isidro Díaz de Mera', ...
# 308410        9  [{'id': 32457, 'name': 'César Soto', 'national...
# 308404        9  [{'id': 43870, 'name': 'Jesús Gil', 'nationali...
#
#                                                     score  season  \
# id
# 235183  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...    2018
# 235184  {'winner': 'DRAW', 'duration': 'REGULAR', 'ful...    2018
# 235185  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...    2018
# 235186  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...    2018
# 235187  {'winner': 'DRAW', 'duration': 'REGULAR', 'ful...    2018
# ...                                                   ...     ...
# 308408  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...    2020
# 308409  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...    2020
# 308406  {'winner': 'DRAW', 'duration': 'REGULAR', 'ful...    2020
# 308410  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...    2020
# 308404  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...    2020
#
#                  stage    status             utcDate     winner  \
# id
# 235183  REGULAR_SEASON  FINISHED 2018-08-10 18:00:00  AWAY_TEAM
# 235184  REGULAR_SEASON  FINISHED 2018-08-11 16:30:00       DRAW
# 235185  REGULAR_SEASON  FINISHED 2018-08-11 16:30:00  AWAY_TEAM
# 235186  REGULAR_SEASON  FINISHED 2018-08-11 18:45:00  HOME_TEAM
# 235187  REGULAR_SEASON  FINISHED 2018-08-11 18:45:00       DRAW
# ...                ...       ...                 ...        ...
# 308408  REGULAR_SEASON  FINISHED 2020-11-08 13:00:00  AWAY_TEAM
# 308409  REGULAR_SEASON  FINISHED 2020-11-08 15:15:00  HOME_TEAM
# 308406  REGULAR_SEASON  FINISHED 2020-11-08 17:30:00       DRAW
# 308410  REGULAR_SEASON  FINISHED 2020-11-08 17:30:00  HOME_TEAM
# 308404  REGULAR_SEASON  FINISHED 2020-11-08 20:00:00  HOME_TEAM
#
#                    homeTeamName      awayTeamName corona league
# id
# 235183               PEC Zwolle     SC Heerenveen    pre    DED
# 235184                 AFC Ajax   Heracles Almelo    pre    DED
# 235185        Willem II Tilburg         VVV Venlo    pre    DED
# 235186                      PSV        FC Utrecht    pre    DED
# 235187            SBV Excelsior   Fortuna Sittard    pre    DED
# ...                         ...               ...    ...    ...
# 308408                Getafe CF     Villarreal CF   post     PD
# 308409  Real Sociedad de Fútbol        Granada CF   post     PD
# 308406               Levante UD  Deportivo Alavés   post     PD
# 308410       Real Valladolid CF     Athletic Club   post     PD
# 308404              Valencia CF    Real Madrid CF   post     PD
#
# [4558 rows x 16 columns]
